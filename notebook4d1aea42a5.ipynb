jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0357.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0387.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0375.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0399.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0322.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0416.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0352.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0315.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0323.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0396.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0378.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0337.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0405.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0342.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0402.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0365.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0403.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0339.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0366.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0304.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0371.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0314.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0377.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0351.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0327.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0309.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0412.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0370.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0400.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0358.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0406.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0390.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0355.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0373.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0346.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0363.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0348.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0332.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0345.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0325.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0347.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0410.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0316.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0344.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0333.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0413.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0364.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0336.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0404.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0392.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0360.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0329.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0386.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0320.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0414.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0308.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0407.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0361.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0395.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0305.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0321.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0317.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0391.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0326.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0385.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0367.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0408.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0335.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0368.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0307.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0401.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0334.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0354.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0384.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0394.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0328.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0356.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0417.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0388.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0411.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0349.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0381.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0299.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0340.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0379.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0359.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0338.jpg
# /kaggle/input/computer-vision-info-educatie/green/IMG-20250529-WA0318.jpg
# /kaggle/input/testing5/WhatsApp Image 2025-05-29 at 22.16.34_288d61ff.jpg
# /kaggle/input/testing4/WhatsApp Image 2025-05-29 at 20.37.58_726d9d0c.jpg
# /kaggle/input/testing2/WhatsApp Image 2025-05-29 at 20.37.31_2cb8c8eb.jpg

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision
import torchvision.transforms as transforms
from PIL import Image
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import classification_report

# %%
path = '/kaggle/input/computer-vision-info-educatie'

# %%
def folder_to_label(color):
    if color == 'yellow':
        return 0
    elif color == 'blue':
        return 0
    elif color == 'green':
        return 0
    return 1

# %%
class data(Dataset):
    def __init__(self, path):
        self.images = []
        self.label = []

        self.transform = transforms.Compose([
            transforms.Resize((224,224)),
            transforms.ToTensor(),
            transforms.RandomAffine(degrees=15, translate=(0.1, 0.1)),
            transforms.RandomHorizontalFlip(),
            transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.05),
            transforms.RandomApply([transforms.Grayscale(num_output_channels=3)], p=1),
            transforms.Normalize( mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])

        for folder in os.listdir(path):
            for img in os.listdir(os.path.join(path, folder)):
                self.images.append(os.path.join(path, folder, img))
                self.label.append(folder_to_label(folder))
                
    def __len__(self):
        return len(self.label)
        
    def __getitem__(self,index):
        input_img = self.transform(Image.open(self.images[index]).convert('RGB'))
        output_label = torch.tensor(self.label[index])
        return input_img, output_label

# %%
dataset = data(path)

# %%
train_dataset, valid_dataset, test_dataset = random_split(dataset, [int(0.8 * len(dataset)), int(0.1 * len(dataset)), len(dataset) - int(0.1 * len(dataset)) - int(0.8 * len(dataset))])
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
valid_dataloader = DataLoader(valid_dataset, batch_size=32, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
def Linear(input_features, output_features):
    layer = nn.Sequential(
        nn.Linear(input_features, output_features),
        nn.ReLU(),
        nn.Dropout(0.4)
    )
    return layer

# %%
def Conv(input_features, output_features, kernel_sz):
    convolution = nn.Sequential(
        nn.Conv2d(in_channels=input_features, out_channels=output_features, kernel_size=kernel_sz, stride = 2),
        nn.BatchNorm2d(output_features),
        nn.ReLU(),
        nn.MaxPool2d((2,2), 2),
        nn.Dropout2d(0.4)
    )
    return convolution

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
from torchvision.models import vit_b_16, ViT_B_16_Weights

# %%
weights = ViT_B_16_Weights.DEFAULT
model = vit_b_16(weights=weights)

in_features = model.heads[0].in_features

model.heads = nn.Sequential(nn.Linear(in_features, 2))
model = model.to(device)

# %%
weight = torch.tensor([1.0, 253 / 78], dtype=torch.float32).to(device)
loss_fn = nn.CrossEntropyLoss(weight=weight)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-5, weight_decay=1e-2)
softmax = nn.Softmax(dim=-1)
epochs = 8

# %%
import matplotlib.pyplot as plt

train_losses = []
valid_losses = []

# %%
for epoch in range(epochs):
    model.train()
    predictions = []
    ground_truth = []
    running_loss = 0.0

    dataloader = tqdm(train_dataloader, desc=f"Training on epoch {epoch + 1}...", leave=False)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        y_hat = model(X)
        loss = loss_fn(y_hat, y)
        running_loss += loss.item()

        preds = torch.argmax(softmax(y_hat), dim=1)
        predictions.extend(preds.cpu().numpy())
        ground_truth.extend(y.cpu().numpy())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    epoch_train_loss = running_loss / len(train_dataloader)
    train_losses.append(epoch_train_loss)
    print(f"Training epoch {epoch + 1} - Loss: {epoch_train_loss:.4f}")
    print("Classification Report (Train):")
    print(classification_report(ground_truth, predictions))

    # Evaluation
    model.eval()
    predictions = []
    ground_truth = []
    running_loss = 0.0

    with torch.no_grad():
        dataloader = tqdm(valid_dataloader, desc=f"Validating on epoch {epoch + 1}...", leave=False)
        for batch, (X, y) in enumerate(dataloader):
            X, y = X.to(device), y.to(device)

            y_hat = model(X)
            loss = loss_fn(y_hat, y)
            running_loss += loss.item()

            preds = torch.argmax(softmax(y_hat), dim=1)
            predictions.extend(preds.cpu().numpy())
            ground_truth.extend(y.cpu().numpy())

    epoch_valid_loss = running_loss / len(valid_dataloader)
    valid_losses.append(epoch_valid_loss)
    print(f"Validation epoch {epoch + 1} - Loss: {epoch_valid_loss:.4f}")
    print("Classification Report (Validation):")
    print(classification_report(ground_truth, predictions))
# Out:
# Training on epoch 1...:  18%|█▊        | 2/11 [00:03<00:14,  1.59s/it]

# %%
# Plot after training
plt.figure(figsize=(10, 5))
plt.plot(range(1, 6), train_losses, label='Training Loss', marker='o')
plt.plot(range(1, 6), valid_losses, label='Validation Loss', marker='x')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# %%
model.eval()
predictions = []
ground_truth = []
running_loss = 0.0

with torch.no_grad():
    dataloader = tqdm(test_dataloader, desc=f"Testing on epoch {epoch + 1}...", leave=False)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        y_hat = model(X)
        loss = loss_fn(y_hat, y)
        running_loss += loss.item()

        preds = torch.argmax(softmax(y_hat), dim=1)
        predictions.extend(preds.cpu().numpy())
        ground_truth.extend(y.cpu().numpy())

running_loss /= len(test_dataloader)
print(f"Validation epoch {epoch + 1} - Loss: {running_loss:.4f}")
print("Classification Report (Testing):")
print(classification_report(ground_truth, predictions))

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %%
img_path = "/kaggle/input/testing5/WhatsApp Image 2025-05-29 at 22.16.34_288d61ff.jpg"
image = Image.open(img_path).convert('RGB')

transformed_image = transform(image)
transformed_image = transformed_image.unsqueeze(0)
transformed_image = transformed_image.to(device)

# %%
with torch.no_grad():
    output = model(transformed_image)
    probs = torch.softmax(output, dim=1)
    print(probs)
    predicted_class = torch.argmax(probs, dim=1).item()

# %%
def color_to_label(color):
    if color == 'yellow':
        return 0
    elif color == 'blue':
        return 1
    return 2

# %%
class data_color(Dataset):
    def __init__(self, path):
        self.images = []
        self.label = []

        self.transform = transforms.Compose([
            transforms.Resize((224,224)),
            transforms.ToTensor(),
            transforms.RandomAffine(degrees=15, translate=(0.1, 0.1)),
            transforms.RandomHorizontalFlip(),
            transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.05),
            transforms.Normalize( mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])

        for folder in os.listdir(path):
            if folder != 'fake':
                for img in os.listdir(os.path.join(path, folder)):
                    self.images.append(os.path.join(path, folder, img))
                    self.label.append(color_to_label(folder))
                
    def __len__(self):
        return len(self.label)
        
    def __getitem__(self,index):
        input_img = self.transform(Image.open(self.images[index]).convert('RGB'))
        output_label = torch.tensor(self.label[index])
        return input_img, output_label

# %%
dataset = data_color(path)

# %%
train_dataset, valid_dataset, test_dataset = random_split(dataset, [int(0.8 * len(dataset)), int(0.1 * len(dataset)), len(dataset) - int(0.1 * len(dataset)) - int(0.8 * len(dataset))])
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
valid_dataloader = DataLoader(valid_dataset, batch_size=32, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
import torchvision.models as models

color_model = models.resnet18(pretrained=True)
color_model.fc = nn.Linear(color_model.fc.in_features, 3) 
color_model = color_model.to(device)

# %%
import matplotlib.pyplot as plt

train_losses = []
valid_losses = []

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(color_model.parameters(), lr = 1e-4)
softmax = nn.Softmax(dim=-1)
epochs = 15

# %%
for epoch in range(epochs):
    color_model.train()
    predictions = []
    ground_truth = []
    running_loss = 0.0

    dataloader = tqdm(train_dataloader, desc=f"Training on epoch {epoch + 1}...", leave=False)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        y_hat = color_model(X)
        loss = loss_fn(y_hat, y)
        running_loss += loss.item()

        preds = torch.argmax(softmax(y_hat), dim=1)
        predictions.extend(preds.cpu().numpy())
        ground_truth.extend(y.cpu().numpy())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    epoch_train_loss = running_loss / len(train_dataloader)
    train_losses.append(epoch_train_loss)
    print(f"Training epoch {epoch + 1} - Loss: {epoch_train_loss:.4f}")
    print("Classification Report (Train):")
    print(classification_report(ground_truth, predictions))

    # Evaluation
    color_model.eval()
    predictions = []
    ground_truth = []
    running_loss = 0.0

    with torch.no_grad():
        dataloader = tqdm(valid_dataloader, desc=f"Validating on epoch {epoch + 1}...", leave=False)
        for batch, (X, y) in enumerate(dataloader):
            X, y = X.to(device), y.to(device)

            y_hat = color_model(X)
            loss = loss_fn(y_hat, y)
            running_loss += loss.item()

            preds = torch.argmax(softmax(y_hat), dim=1)
            predictions.extend(preds.cpu().numpy())
            ground_truth.extend(y.cpu().numpy())

    epoch_valid_loss = running_loss / len(valid_dataloader)
    valid_losses.append(epoch_valid_loss)
    print(f"Validation epoch {epoch + 1} - Loss: {epoch_valid_loss:.4f}")
    print("Classification Report (Validation):")
    print(classification_report(ground_truth, predictions))

# %%
# Plot after training
plt.figure(figsize=(10, 5))
plt.plot(range(1, 3 + 1), train_losses, label='Training Loss', marker='o')
plt.plot(range(1, 3 + 1), valid_losses, label='Validation Loss', marker='x')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# %%
color_model.eval()
predictions = []
ground_truth = []
running_loss = 0.0

with torch.no_grad():
    dataloader = tqdm(test_dataloader, desc=f"Testing on epoch {epoch + 1}...", leave=False)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        y_hat = color_model(X)
        loss = loss_fn(y_hat, y)
        running_loss += loss.item()

        preds = torch.argmax(softmax(y_hat), dim=1)
        predictions.extend(preds.cpu().numpy())
        ground_truth.extend(y.cpu().numpy())

running_loss /= len(test_dataloader)
print(f"Validation epoch {epoch + 1} - Loss: {running_loss:.4f}")
print("Classification Report (Testing):")
print(classification_report(ground_truth, predictions))
